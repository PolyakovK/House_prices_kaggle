# %%
import numpy as np
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
import sklearn
sklearn.set_config(transform_output="pandas")
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler, MinMaxScaler, OrdinalEncoder
from sklearn.model_selection import GridSearchCV, KFold
from category_encoders import CatBoostEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_log_error
from sklearn.linear_model import LinearRegression
import optuna
from sklearn.model_selection import KFold
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import Lasso
from sklearn.preprocessing import FunctionTransformer
import joblib

# %% [markdown]
# ### Подгружаем датасет

# %%
train = pd.read_csv('/Users/polyakovk/ds_bootcamp/House_prices_kaggle/train.csv', index_col='Id')
test = pd.read_csv('/Users/polyakovk/ds_bootcamp/House_prices_kaggle/test.csv', index_col='Id')

# %% [markdown]
# ### Объединяем в один

# %%
df = [train, test]
df = pd.concat(df)

# %% [markdown]
# ### Отделяем целевую переменную

# %%
X, y = df.drop('SalePrice',axis=1), df['SalePrice']

# %% [markdown]
# ### Избавляемся от пропусков в данных
# выводим числовые и категориальные признаки
# там, где в признаках значение nan обусловлено отсутствием меняем на значение "Unknown"
# там, где пропуски случайны, заполняем модой для категориальных и медианой для числовых

# %%
numeric_features = X.select_dtypes(include=['number']).columns.tolist()
categorical_features = X.select_dtypes(include=['object']).columns.tolist()
print(list(categorical_features))
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
# Заполнение пропусков в категориальных   
replace_nan_col = ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu',
                   'GarageType','GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']  # меняем значение nan на отсутствует
fill_mode_col = ['Alley', 'Electrical', ] # заполняем модой

median_impute_columns = numeric_features


# Удаление столбцов и заполнение пропусков в категориальных
imputer = ColumnTransformer(
    transformers = [
        ('replace', SimpleImputer(strategy='constant', fill_value='Unknown'), replace_nan_col),
        ('fill_mode', SimpleImputer(strategy='most_frequent'), fill_mode_col),
        ('median_imputer', SimpleImputer(strategy='median'), median_impute_columns),
    ],
    verbose_feature_names_out = False,
    remainder = 'passthrough' 
)

# %% [markdown]
# ### Feature ingenering

# %%
def create_features(df):
    df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']
    df['OverallGrade'] = df['OverallQual'] * df['OverallCond']
    df['AgeAtSale'] = df['YrSold'] - df['YearBuilt']
    df['TotalBathrooms'] = df['FullBath'] + df['HalfBath']*0.5 + df['BsmtFullBath'] + df['BsmtHalfBath']*0.5
    
    
    # Удаление старых признаков, которые были использованы для создания новых
    drop_columns = ['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'OverallQual', 'OverallCond', 
                    'YearBuilt', 'YrSold', 'FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath', 'Alley', 'MiscFeature']
    df = df.drop(columns=drop_columns)
    
    return df

drop_columns = ['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'OverallQual', 'OverallCond', 
                    'YearBuilt', 'YrSold', 'FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath', 'Alley', 'MiscFeature',
                    'GarageQual', 'GarageCond']
new_feature = ['TotalSF', 'OverallGrade', 'AgeAtSale', 'TotalBathrooms']


# Создание пользовательского трансформера
feature_creator = FunctionTransformer(create_features, validate=False)

# %% [markdown]
# ### Кодирование и нормировка
# one-hot - для признаков с небошим кол-вом значений
# ordinal - для признаков явно указывающих на градацию
# cat-boost - для признаков с большим количеством не связанных значений
# StandardScaler - для номировки числовых данных

# %%
numeric_features = numeric_features + new_feature
numeric_features = [item for item in numeric_features if item not in drop_columns]

one_hot_encoding_columns = ['Street', 'CentralAir', 'PavedDrive', ]
ordinal_encoding_columns = ['BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageQual', 'GarageCond', 'PoolQC',
                            'Fence', 'LandSlope', 'ExterQual', 'ExterCond', 'HeatingQC', 'KitchenQual', ]
catboost_ecncoding_columns = ['MasVnrType', 'BsmtQual', 'BsmtCond', 'GarageType', 'GarageFinish', 'Electrical','MSZoning', 'LotShape',
                              'LandContour', 'Utilities', 'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 
                              'HouseStyle', 'RoofStyle', 'RoofMatl','Exterior1st', 'Exterior2nd', 'Foundation', 'Heating', 'Functional', 'SaleType', 'SaleCondition']


scaler_encoder = ColumnTransformer(
    [
        ('one_hot_encoding', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), one_hot_encoding_columns),
        ('ordinal_encoding', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ordinal_encoding_columns),
        ('catboost_encoding_columns', CatBoostEncoder(), catboost_ecncoding_columns),
        ('scaler', StandardScaler(), numeric_features),
    ],
    verbose_feature_names_out = False,
    remainder = 'passthrough' 
)

# %% [markdown]
# ### Собираем препроцессор

# %%
preprocessor = Pipeline(
    [
        ('imputer', imputer),
        ('feature_creator', feature_creator),
        ('scaler_encoder', scaler_encoder)
    ]
)

# %% [markdown]
# ### Делим датафрейм в изначальных пропорциях и логарифмируем целевую переменную

# %%
X_train = pd.DataFrame(X[:1460])
test  = pd.DataFrame(X[1460:])
y_train = pd.Series(y[:1460])
y_train = np.log1p(y_train)

# %% [markdown]
# ### Дополнительное разбиение train выборки на train и valid для тестов на размеченных данных

# %%
# X_train1, X_valid, Y_train1, Y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2,random_state=42)

# %% [markdown]
# ### Подбор гиперпараметров через Optuna
# Для подбора параметров, необходимо обучить и трансформировать данные через препроцессор и передать в оптюну
# затем записать лучшие параметры и передать в модель, перезапустив весь код, без транформа в препроцессор

# %%
# X_train = preprocessor.fit_transform(X_train, y_train)

# %%
# def objective(trial):
#     params = {
#         'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
#         'depth': trial.suggest_int('depth', 3, 10),
#         'subsample': trial.suggest_uniform('subsample', 0.6, 0.95),
#         'colsample_bylevel': trial.suggest_uniform('colsample_bylevel', 0.6, 0.95),
#         'random_state': 42,
#         'loss_function': 'RMSE',
#         'logging_level': 'Silent'
#     }
    
#     model = CatBoostRegressor(**params)
#     cv = KFold(n_splits=5, random_state=42, shuffle=True)
#     scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='neg_mean_squared_log_error')
#     rmsle = np.sqrt(-scores.mean())  # Конвертация в RMSLE
    
#     return rmsle

# # Создание и запуск оптимизации с помощью Optuna
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=100)

# best_params = study.best_params
# best_rmsle = study.best_value

# print(f"Лучшие параметры: {best_params}")
# print(f"Лучшее значение RMSLE: {best_rmsle}")

# %% [markdown]
# # Лучшие параметры из оптюны

# %%
# старые ИСПОЛЬЗОВАТЬ ЭТИ
best_params = {'n_estimators': 800, 'learning_rate': 0.050939168701603, 'depth': 5, 'subsample': 0.8217157756680307, 'colsample_bylevel': 0.6002185179366489}

# %%
# # новые
# best_params = {'n_estimators': 900, 'learning_rate': 0.032881543434917726, 'depth': 6, 'subsample': 0.7790632706804598, 'colsample_bylevel': 0.9034758823706623}

# %% [markdown]
# ### Собираем в пайплайн препроцессор и модель используя лучшие параметры из Optuna
# Обучаем модель на train части выборки

# %%
CB = CatBoostRegressor(**best_params)

ml_pipeline_CB = Pipeline(
    [
        ('preprocessor', preprocessor),
        ('model', CB)
    ]
)

ml_pipeline_CB.fit(X_train, y_train)
# Out:
# 0:	learn: 0.3860310	total: 60.5ms	remaining: 48.3s
# 1:	learn: 0.3736647	total: 61.9ms	remaining: 24.7s
# 2:	learn: 0.3619068	total: 63.3ms	remaining: 16.8s
# 3:	learn: 0.3510050	total: 64.6ms	remaining: 12.9s
# 4:	learn: 0.3418292	total: 66ms	remaining: 10.5s
# 5:	learn: 0.3309604	total: 67ms	remaining: 8.86s
# 6:	learn: 0.3217859	total: 68ms	remaining: 7.7s
# 7:	learn: 0.3112638	total: 68.9ms	remaining: 6.82s
# 8:	learn: 0.3023124	total: 70ms	remaining: 6.15s
# 9:	learn: 0.2935731	total: 71ms	remaining: 5.61s
# 10:	learn: 0.2853201	total: 72.3ms	remaining: 5.18s
# 11:	learn: 0.2771047	total: 73.6ms	remaining: 4.83s
# 12:	learn: 0.2693552	total: 74.9ms	remaining: 4.54s
# 13:	learn: 0.2621020	total: 76ms	remaining: 4.27s
# 14:	learn: 0.2561453	total: 77ms	remaining: 4.03s
# 15:	learn: 0.2492491	total: 78.2ms	remaining: 3.83s
# 16:	learn: 0.2436322	total: 79.8ms	remaining: 3.67s
# 17:	learn: 0.2377933	total: 80.9ms	remaining: 3.51s
# 18:	learn: 0.2322306	total: 81.8ms	remaining: 3.36s
# 19:	learn: 0.2269811	total: 82.7ms	remaining: 3.23s
# 20:	learn: 0.2220308	total: 83.7ms	remaining: 3.1s
# 21:	learn: 0.2174183	total: 84.6ms	remaining: 2.99s
# 22:	learn: 0.2121508	total: 85.5ms	remaining: 2.89s
# 23:	learn: 0.2077414	total: 86.9ms	remaining: 2.81s
# 24:	learn: 0.2032333	total: 87.7ms	remaining: 2.72s
# 25:	learn: 0.1991441	total: 88.6ms	remaining: 2.64s
# 26:	learn: 0.1956366	total: 89.5ms	remaining: 2.56s
# 27:	learn: 0.1921126	total: 90.6ms	remaining: 2.5s
# 28:	learn: 0.1883869	total: 91.5ms	remaining: 2.43s
# 29:	learn: 0.1851710	total: 92.5ms	remaining: 2.37s
# 30:	learn: 0.1820051	total: 93.4ms	remaining: 2.32s
# 31:	learn: 0.1789983	total: 94.3ms	remaining: 2.26s
# 32:	learn: 0.1762700	total: 95.2ms	remaining: 2.21s
# 33:	learn: 0.1733585	total: 96.1ms	remaining: 2.17s
# 34:	learn: 0.1708231	total: 96.9ms	remaining: 2.12s
# 35:	learn: 0.1684291	total: 97.7ms	remaining: 2.07s
# 36:	learn: 0.1661186	total: 98.8ms	remaining: 2.04s
# 37:	learn: 0.1637818	total: 99.9ms	remaining: 2s
# 38:	learn: 0.1615256	total: 101ms	remaining: 1.97s
# 39:	learn: 0.1597872	total: 102ms	remaining: 1.93s
# 40:	learn: 0.1578709	total: 103ms	remaining: 1.9s
# 41:	learn: 0.1559965	total: 104ms	remaining: 1.87s
# 42:	learn: 0.1541580	total: 104ms	remaining: 1.84s
# 43:	learn: 0.1525546	total: 105ms	remaining: 1.81s
# 44:	learn: 0.1509420	total: 106ms	remaining: 1.78s
# 45:	learn: 0.1493415	total: 107ms	remaining: 1.76s
# 46:	learn: 0.1482051	total: 108ms	remaining: 1.73s
# 47:	learn: 0.1467532	total: 109ms	remaining: 1.71s
# 48:	learn: 0.1455494	total: 110ms	remaining: 1.68s
# 49:	learn: 0.1445403	total: 111ms	remaining: 1.66s
# 50:	learn: 0.1431497	total: 112ms	remaining: 1.64s
# 51:	learn: 0.1418371	total: 113ms	remaining: 1.62s
# 52:	learn: 0.1406104	total: 114ms	remaining: 1.61s
# 53:	learn: 0.1394074	total: 115ms	remaining: 1.59s
# 54:	learn: 0.1382539	total: 116ms	remaining: 1.57s
# 55:	learn: 0.1372490	total: 117ms	remaining: 1.55s
# 56:	learn: 0.1361935	total: 118ms	remaining: 1.53s
# 57:	learn: 0.1353796	total: 119ms	remaining: 1.52s
# 58:	learn: 0.1344417	total: 120ms	remaining: 1.5s
# 59:	learn: 0.1336693	total: 121ms	remaining: 1.49s
# 60:	learn: 0.1326396	total: 122ms	remaining: 1.47s
# 61:	learn: 0.1318522	total: 122ms	remaining: 1.46s
# 62:	learn: 0.1309434	total: 123ms	remaining: 1.44s
# 63:	learn: 0.1300749	total: 124ms	remaining: 1.43s
# 64:	learn: 0.1292790	total: 125ms	remaining: 1.41s
# 65:	learn: 0.1286327	total: 126ms	remaining: 1.4s
# 66:	learn: 0.1279669	total: 127ms	remaining: 1.39s
# 67:	learn: 0.1271870	total: 128ms	remaining: 1.37s
# 68:	learn: 0.1265596	total: 129ms	remaining: 1.36s
# 69:	learn: 0.1260076	total: 130ms	remaining: 1.36s
# 70:	learn: 0.1254089	total: 131ms	remaining: 1.35s
# 71:	learn: 0.1250289	total: 132ms	remaining: 1.34s
# 72:	learn: 0.1244681	total: 133ms	remaining: 1.33s
# 73:	learn: 0.1239304	total: 134ms	remaining: 1.32s
# 74:	learn: 0.1233132	total: 135ms	remaining: 1.31s
# 75:	learn: 0.1226812	total: 136ms	remaining: 1.29s
# 76:	learn: 0.1221544	total: 137ms	remaining: 1.28s
# 77:	learn: 0.1215790	total: 138ms	remaining: 1.27s
# 78:	learn: 0.1210340	total: 139ms	remaining: 1.26s
# 79:	learn: 0.1206031	total: 140ms	remaining: 1.26s
# 80:	learn: 0.1201589	total: 141ms	remaining: 1.25s
# 81:	learn: 0.1197782	total: 142ms	remaining: 1.24s
# 82:	learn: 0.1194212	total: 143ms	remaining: 1.23s
# 83:	learn: 0.1189086	total: 144ms	remaining: 1.22s
# 84:	learn: 0.1184895	total: 145ms	remaining: 1.22s
# 85:	learn: 0.1181417	total: 146ms	remaining: 1.21s
# 86:	learn: 0.1178203	total: 147ms	remaining: 1.2s
# 87:	learn: 0.1173255	total: 148ms	remaining: 1.2s
# 88:	learn: 0.1169200	total: 149ms	remaining: 1.19s
# 89:	learn: 0.1166089	total: 150ms	remaining: 1.18s
# 90:	learn: 0.1162500	total: 150ms	remaining: 1.17s
# 91:	learn: 0.1157752	total: 152ms	remaining: 1.17s
# 92:	learn: 0.1155670	total: 153ms	remaining: 1.16s
# 93:	learn: 0.1153111	total: 154ms	remaining: 1.16s
# 94:	learn: 0.1149361	total: 155ms	remaining: 1.15s
# 95:	learn: 0.1146708	total: 156ms	remaining: 1.14s
# 96:	learn: 0.1143261	total: 157ms	remaining: 1.14s
# 97:	learn: 0.1140587	total: 157ms	remaining: 1.13s
# 98:	learn: 0.1136747	total: 158ms	remaining: 1.12s
# 99:	learn: 0.1133392	total: 159ms	remaining: 1.11s
# 100:	learn: 0.1130545	total: 160ms	remaining: 1.11s
# 101:	learn: 0.1126198	total: 161ms	remaining: 1.1s
# 102:	learn: 0.1123179	total: 162ms	remaining: 1.1s
# 103:	learn: 0.1119857	total: 163ms	remaining: 1.09s
# 104:	learn: 0.1116982	total: 164ms	remaining: 1.08s
# 105:	learn: 0.1113832	total: 165ms	remaining: 1.08s
# 106:	learn: 0.1110886	total: 165ms	remaining: 1.07s
# 107:	learn: 0.1107961	total: 166ms	remaining: 1.07s
# 108:	learn: 0.1104980	total: 167ms	remaining: 1.06s
# 109:	learn: 0.1102196	total: 168ms	remaining: 1.05s
# 110:	learn: 0.1099472	total: 169ms	remaining: 1.05s
# 111:	learn: 0.1097052	total: 170ms	remaining: 1.04s
# 112:	learn: 0.1094871	total: 171ms	remaining: 1.04s
# 113:	learn: 0.1092304	total: 172ms	remaining: 1.03s
# 114:	learn: 0.1089651	total: 173ms	remaining: 1.03s
# 115:	learn: 0.1086707	total: 174ms	remaining: 1.02s
# 116:	learn: 0.1083868	total: 175ms	remaining: 1.02s
# 117:	learn: 0.1081281	total: 176ms	remaining: 1.02s
# 118:	learn: 0.1079256	total: 177ms	remaining: 1.01s
# 119:	learn: 0.1077710	total: 178ms	remaining: 1.01s
# 120:	learn: 0.1075626	total: 179ms	remaining: 1s
# 121:	learn: 0.1073000	total: 181ms	remaining: 1s
# 122:	learn: 0.1070236	total: 181ms	remaining: 998ms
# 123:	learn: 0.1068166	total: 182ms	remaining: 994ms
# 124:	learn: 0.1066994	total: 183ms	remaining: 988ms
# 125:	learn: 0.1064812	total: 184ms	remaining: 983ms
# 126:	learn: 0.1063528	total: 185ms	remaining: 979ms
# 127:	learn: 0.1060697	total: 186ms	remaining: 974ms
# 128:	learn: 0.1058213	total: 187ms	remaining: 971ms
# 129:	learn: 0.1056336	total: 188ms	remaining: 966ms
# 130:	learn: 0.1055903	total: 188ms	remaining: 962ms
# 131:	learn: 0.1053753	total: 189ms	remaining: 958ms
# 132:	learn: 0.1052228	total: 190ms	remaining: 954ms
# 133:	learn: 0.1049643	total: 191ms	remaining: 950ms
# 134:	learn: 0.1047696	total: 192ms	remaining: 946ms
# 135:	learn: 0.1046079	total: 193ms	remaining: 942ms
# 136:	learn: 0.1044148	total: 194ms	remaining: 939ms
# 137:	learn: 0.1042934	total: 195ms	remaining: 935ms
# 138:	learn: 0.1040574	total: 196ms	remaining: 932ms
# 139:	learn: 0.1038377	total: 197ms	remaining: 927ms
# 140:	learn: 0.1036449	total: 198ms	remaining: 924ms
# 141:	learn: 0.1034751	total: 199ms	remaining: 921ms
# 142:	learn: 0.1032457	total: 200ms	remaining: 917ms
# 143:	learn: 0.1030243	total: 201ms	remaining: 914ms
# 144:	learn: 0.1028694	total: 201ms	remaining: 910ms
# 145:	learn: 0.1026929	total: 202ms	remaining: 906ms
# 146:	learn: 0.1024810	total: 203ms	remaining: 903ms
# 147:	learn: 0.1023239	total: 204ms	remaining: 899ms
# 148:	learn: 0.1021657	total: 205ms	remaining: 895ms
# 149:	learn: 0.1019752	total: 206ms	remaining: 892ms
# 150:	learn: 0.1017480	total: 207ms	remaining: 891ms
# 151:	learn: 0.1015680	total: 208ms	remaining: 887ms
# 152:	learn: 0.1013286	total: 209ms	remaining: 884ms
# 153:	learn: 0.1011262	total: 210ms	remaining: 880ms
# 154:	learn: 0.1008668	total: 211ms	remaining: 877ms
# 155:	learn: 0.1007997	total: 212ms	remaining: 875ms
# 156:	learn: 0.1006327	total: 213ms	remaining: 871ms
# 157:	learn: 0.1004512	total: 214ms	remaining: 868ms
# 158:	learn: 0.1003633	total: 215ms	remaining: 865ms
# 159:	learn: 0.1001598	total: 215ms	remaining: 862ms
# 160:	learn: 0.1000432	total: 216ms	remaining: 858ms
# 161:	learn: 0.0998104	total: 217ms	remaining: 855ms
# 162:	learn: 0.0996845	total: 218ms	remaining: 852ms
# 163:	learn: 0.0994932	total: 219ms	remaining: 849ms
# 164:	learn: 0.0994112	total: 220ms	remaining: 847ms
# 165:	learn: 0.0991469	total: 222ms	remaining: 846ms
# 166:	learn: 0.0989841	total: 223ms	remaining: 844ms
# 167:	learn: 0.0988007	total: 223ms	remaining: 841ms
# 168:	learn: 0.0985939	total: 224ms	remaining: 838ms
# 169:	learn: 0.0984605	total: 225ms	remaining: 835ms
# 170:	learn: 0.0983758	total: 226ms	remaining: 832ms
# 171:	learn: 0.0982709	total: 227ms	remaining: 830ms
# 172:	learn: 0.0981364	total: 228ms	remaining: 828ms
# 173:	learn: 0.0979038	total: 229ms	remaining: 825ms
# 174:	learn: 0.0977333	total: 230ms	remaining: 822ms
# 175:	learn: 0.0974937	total: 231ms	remaining: 819ms
# 176:	learn: 0.0973917	total: 232ms	remaining: 816ms
# 177:	learn: 0.0973167	total: 233ms	remaining: 814ms
# 178:	learn: 0.0972410	total: 234ms	remaining: 811ms
# 179:	learn: 0.0971463	total: 235ms	remaining: 809ms
# 180:	learn: 0.0969762	total: 236ms	remaining: 806ms
# 181:	learn: 0.0968194	total: 237ms	remaining: 804ms
# 182:	learn: 0.0966783	total: 238ms	remaining: 801ms
# 183:	learn: 0.0965429	total: 239ms	remaining: 799ms
# 184:	learn: 0.0963316	total: 239ms	remaining: 796ms
# 185:	learn: 0.0962155	total: 240ms	remaining: 793ms
# 186:	learn: 0.0960968	total: 241ms	remaining: 791ms
# 187:	learn: 0.0960285	total: 242ms	remaining: 788ms
# 188:	learn: 0.0959320	total: 243ms	remaining: 785ms
# 189:	learn: 0.0957359	total: 244ms	remaining: 783ms
# 190:	learn: 0.0955869	total: 245ms	remaining: 780ms
# 191:	learn: 0.0954694	total: 246ms	remaining: 777ms
# 192:	learn: 0.0952863	total: 246ms	remaining: 775ms
# 193:	learn: 0.0950835	total: 247ms	remaining: 772ms
# 194:	learn: 0.0949433	total: 248ms	remaining: 770ms
# 195:	learn: 0.0948821	total: 249ms	remaining: 768ms
# 196:	learn: 0.0946576	total: 250ms	remaining: 766ms
# 197:	learn: 0.0944418	total: 251ms	remaining: 764ms
# 198:	learn: 0.0942780	total: 252ms	remaining: 762ms
# 199:	learn: 0.0941121	total: 254ms	remaining: 761ms
# 200:	learn: 0.0939453	total: 255ms	remaining: 759ms
# 201:	learn: 0.0938415	total: 255ms	remaining: 756ms
# 202:	learn: 0.0936772	total: 256ms	remaining: 754ms
# 203:	learn: 0.0935610	total: 257ms	remaining: 751ms
# 204:	learn: 0.0934933	total: 258ms	remaining: 749ms
# 205:	learn: 0.0933812	total: 259ms	remaining: 747ms
# 206:	learn: 0.0931707	total: 260ms	remaining: 745ms
# 207:	learn: 0.0929611	total: 261ms	remaining: 742ms
# 208:	learn: 0.0928921	total: 262ms	remaining: 740ms
# 209:	learn: 0.0928061	total: 263ms	remaining: 738ms
# 210:	learn: 0.0926835	total: 264ms	remaining: 736ms
# 211:	learn: 0.0925442	total: 265ms	remaining: 734ms
# 212:	learn: 0.0923581	total: 265ms	remaining: 732ms
# 213:	learn: 0.0921995	total: 266ms	remaining: 730ms
# 214:	learn: 0.0921210	total: 268ms	remaining: 729ms
# 215:	learn: 0.0919452	total: 269ms	remaining: 727ms
# 216:	learn: 0.0919066	total: 270ms	remaining: 726ms
# 217:	learn: 0.0917278	total: 272ms	remaining: 725ms
# 218:	learn: 0.0915678	total: 273ms	remaining: 723ms
# 219:	learn: 0.0914314	total: 274ms	remaining: 722ms
# 220:	learn: 0.0913680	total: 275ms	remaining: 720ms
# 221:	learn: 0.0912327	total: 276ms	remaining: 718ms
# 222:	learn: 0.0911004	total: 277ms	remaining: 716ms
# 223:	learn: 0.0909261	total: 278ms	remaining: 715ms
# 224:	learn: 0.0908581	total: 279ms	remaining: 713ms
# 225:	learn: 0.0906847	total: 280ms	remaining: 711ms
# 226:	learn: 0.0905419	total: 281ms	remaining: 709ms
# 227:	learn: 0.0904894	total: 282ms	remaining: 707ms
# 228:	learn: 0.0903257	total: 283ms	remaining: 705ms
# 229:	learn: 0.0900983	total: 283ms	remaining: 703ms
# 230:	learn: 0.0899723	total: 285ms	remaining: 701ms
# 231:	learn: 0.0898124	total: 285ms	remaining: 699ms
# 232:	learn: 0.0896606	total: 286ms	remaining: 697ms
# 233:	learn: 0.0895399	total: 287ms	remaining: 695ms
# 234:	learn: 0.0893624	total: 288ms	remaining: 693ms
# 235:	learn: 0.0891399	total: 289ms	remaining: 691ms
# 236:	learn: 0.0890052	total: 290ms	remaining: 689ms
# 237:	learn: 0.0888112	total: 291ms	remaining: 687ms
# 238:	learn: 0.0886428	total: 292ms	remaining: 685ms
# 239:	learn: 0.0885391	total: 293ms	remaining: 683ms
# 240:	learn: 0.0883490	total: 294ms	remaining: 681ms
# 241:	learn: 0.0881473	total: 295ms	remaining: 681ms
# 242:	learn: 0.0880165	total: 296ms	remaining: 679ms
# 243:	learn: 0.0878812	total: 297ms	remaining: 677ms
# 244:	learn: 0.0877008	total: 298ms	remaining: 675ms
# 245:	learn: 0.0875354	total: 299ms	remaining: 673ms
# 246:	learn: 0.0874585	total: 300ms	remaining: 671ms
# 247:	learn: 0.0873500	total: 301ms	remaining: 669ms
# 248:	learn: 0.0872030	total: 302ms	remaining: 667ms
# 249:	learn: 0.0871059	total: 302ms	remaining: 665ms
# 250:	learn: 0.0870038	total: 304ms	remaining: 664ms
# 251:	learn: 0.0869495	total: 304ms	remaining: 662ms
# 252:	learn: 0.0867751	total: 305ms	remaining: 660ms
# 253:	learn: 0.0867089	total: 306ms	remaining: 659ms
# 254:	learn: 0.0865513	total: 307ms	remaining: 657ms
# 255:	learn: 0.0864825	total: 308ms	remaining: 655ms
# 256:	learn: 0.0863394	total: 309ms	remaining: 653ms
# 257:	learn: 0.0862647	total: 310ms	remaining: 651ms
# 258:	learn: 0.0861058	total: 311ms	remaining: 650ms
# 259:	learn: 0.0860792	total: 312ms	remaining: 648ms
# 260:	learn: 0.0860145	total: 313ms	remaining: 646ms
# 261:	learn: 0.0859244	total: 314ms	remaining: 644ms
# 262:	learn: 0.0858908	total: 315ms	remaining: 642ms
# 263:	learn: 0.0858448	total: 316ms	remaining: 641ms
# 264:	learn: 0.0857206	total: 317ms	remaining: 639ms
# 265:	learn: 0.0855339	total: 318ms	remaining: 638ms
# 266:	learn: 0.0854563	total: 319ms	remaining: 636ms
# 267:	learn: 0.0853238	total: 320ms	remaining: 635ms
# 268:	learn: 0.0852738	total: 321ms	remaining: 633ms
# 269:	learn: 0.0851706	total: 322ms	remaining: 631ms
# 270:	learn: 0.0851311	total: 322ms	remaining: 629ms
# 271:	learn: 0.0850360	total: 323ms	remaining: 628ms
# 272:	learn: 0.0849267	total: 324ms	remaining: 626ms
# 273:	learn: 0.0848471	total: 325ms	remaining: 624ms
# 274:	learn: 0.0846574	total: 326ms	remaining: 623ms
# 275:	learn: 0.0845592	total: 327ms	remaining: 621ms
# 276:	learn: 0.0843884	total: 328ms	remaining: 619ms
# 277:	learn: 0.0842024	total: 329ms	remaining: 617ms
# 278:	learn: 0.0840599	total: 330ms	remaining: 616ms
# 279:	learn: 0.0839530	total: 331ms	remaining: 614ms
# 280:	learn: 0.0838771	total: 332ms	remaining: 613ms
# 281:	learn: 0.0837891	total: 333ms	remaining: 611ms
# 282:	learn: 0.0836271	total: 333ms	remaining: 609ms
# 283:	learn: 0.0834533	total: 334ms	remaining: 607ms
# 284:	learn: 0.0832763	total: 335ms	remaining: 606ms
# 285:	learn: 0.0831845	total: 336ms	remaining: 604ms
# 286:	learn: 0.0830408	total: 337ms	remaining: 603ms
# 287:	learn: 0.0829080	total: 338ms	remaining: 601ms
# 288:	learn: 0.0828211	total: 339ms	remaining: 600ms
# 289:	learn: 0.0827548	total: 340ms	remaining: 598ms
# 290:	learn: 0.0827061	total: 341ms	remaining: 597ms
# 291:	learn: 0.0826409	total: 342ms	remaining: 595ms
# 292:	learn: 0.0824833	total: 343ms	remaining: 593ms
# 293:	learn: 0.0824292	total: 344ms	remaining: 591ms
# 294:	learn: 0.0823769	total: 345ms	remaining: 590ms
# 295:	learn: 0.0823533	total: 346ms	remaining: 588ms
# 296:	learn: 0.0822723	total: 347ms	remaining: 587ms
# 297:	learn: 0.0821307	total: 347ms	remaining: 585ms
# 298:	learn: 0.0819740	total: 348ms	remaining: 584ms
# 299:	learn: 0.0819263	total: 349ms	remaining: 582ms
# 300:	learn: 0.0818960	total: 350ms	remaining: 581ms
# 301:	learn: 0.0818002	total: 351ms	remaining: 579ms
# 302:	learn: 0.0817413	total: 352ms	remaining: 578ms
# 303:	learn: 0.0816124	total: 353ms	remaining: 576ms
# 304:	learn: 0.0814463	total: 354ms	remaining: 575ms
# 305:	learn: 0.0812638	total: 355ms	remaining: 573ms
# 306:	learn: 0.0812225	total: 356ms	remaining: 572ms
# 307:	learn: 0.0811054	total: 357ms	remaining: 570ms
# 308:	learn: 0.0810256	total: 358ms	remaining: 569ms
# 309:	learn: 0.0808573	total: 359ms	remaining: 567ms
# 310:	learn: 0.0807769	total: 360ms	remaining: 566ms
# 311:	learn: 0.0807244	total: 361ms	remaining: 564ms
# 312:	learn: 0.0805547	total: 361ms	remaining: 562ms
# 313:	learn: 0.0804170	total: 362ms	remaining: 561ms
# 314:	learn: 0.0802551	total: 363ms	remaining: 559ms
# 315:	learn: 0.0800955	total: 364ms	remaining: 558ms
# 316:	learn: 0.0799770	total: 365ms	remaining: 556ms
# 317:	learn: 0.0798501	total: 366ms	remaining: 555ms
# 318:	learn: 0.0798371	total: 367ms	remaining: 553ms
# 319:	learn: 0.0797247	total: 368ms	remaining: 552ms
# 320:	learn: 0.0796312	total: 369ms	remaining: 550ms
# 321:	learn: 0.0796139	total: 370ms	remaining: 549ms
# 322:	learn: 0.0795869	total: 371ms	remaining: 547ms
# 323:	learn: 0.0795606	total: 372ms	remaining: 546ms
# 324:	learn: 0.0794419	total: 373ms	remaining: 545ms
# 325:	learn: 0.0794043	total: 374ms	remaining: 543ms
# 326:	learn: 0.0793803	total: 375ms	remaining: 542ms
# 327:	learn: 0.0793292	total: 375ms	remaining: 540ms
# 328:	learn: 0.0792029	total: 376ms	remaining: 539ms
# 329:	learn: 0.0791378	total: 377ms	remaining: 537ms
# 330:	learn: 0.0789934	total: 379ms	remaining: 536ms
# 331:	learn: 0.0789044	total: 380ms	remaining: 535ms
# 332:	learn: 0.0788927	total: 380ms	remaining: 534ms
# 333:	learn: 0.0787751	total: 381ms	remaining: 532ms
# 334:	learn: 0.0786198	total: 382ms	remaining: 531ms
# 335:	learn: 0.0784565	total: 384ms	remaining: 530ms
# 336:	learn: 0.0783565	total: 385ms	remaining: 529ms
# 337:	learn: 0.0782534	total: 386ms	remaining: 527ms
# 338:	learn: 0.0782342	total: 387ms	remaining: 526ms
# 339:	learn: 0.0780911	total: 387ms	remaining: 524ms
# 340:	learn: 0.0780284	total: 388ms	remaining: 523ms
# 341:	learn: 0.0779997	total: 389ms	remaining: 521ms
# 342:	learn: 0.0779054	total: 390ms	remaining: 520ms
# 343:	learn: 0.0778411	total: 391ms	remaining: 518ms
# 344:	learn: 0.0778133	total: 392ms	remaining: 517ms
# 345:	learn: 0.0777281	total: 393ms	remaining: 516ms
# 346:	learn: 0.0776304	total: 394ms	remaining: 514ms
# 347:	learn: 0.0775466	total: 395ms	remaining: 513ms
# 348:	learn: 0.0773864	total: 396ms	remaining: 511ms
# 349:	learn: 0.0773536	total: 397ms	remaining: 510ms
# 350:	learn: 0.0772456	total: 397ms	remaining: 508ms
# 351:	learn: 0.0772108	total: 398ms	remaining: 507ms
# 352:	learn: 0.0770768	total: 399ms	remaining: 506ms
# 353:	learn: 0.0770164	total: 400ms	remaining: 504ms
# 354:	learn: 0.0769354	total: 401ms	remaining: 503ms
# 355:	learn: 0.0768284	total: 402ms	remaining: 501ms
# 356:	learn: 0.0766896	total: 403ms	remaining: 500ms
# 357:	learn: 0.0765763	total: 404ms	remaining: 498ms
# 358:	learn: 0.0765150	total: 404ms	remaining: 497ms
# 359:	learn: 0.0764341	total: 405ms	remaining: 496ms
# 360:	learn: 0.0763207	total: 406ms	remaining: 494ms
# 361:	learn: 0.0762492	total: 407ms	remaining: 493ms
# 362:	learn: 0.0762250	total: 408ms	remaining: 491ms
# 363:	learn: 0.0761128	total: 409ms	remaining: 490ms
# 364:	learn: 0.0760194	total: 410ms	remaining: 488ms
# 365:	learn: 0.0758905	total: 411ms	remaining: 487ms
# 366:	learn: 0.0757627	total: 412ms	remaining: 486ms
# 367:	learn: 0.0757471	total: 413ms	remaining: 484ms
# 368:	learn: 0.0756362	total: 414ms	remaining: 483ms
# 369:	learn: 0.0756135	total: 415ms	remaining: 482ms
# 370:	learn: 0.0755766	total: 415ms	remaining: 480ms
# 371:	learn: 0.0755254	total: 417ms	remaining: 479ms
# 372:	learn: 0.0754700	total: 418ms	remaining: 478ms
# 373:	learn: 0.0753518	total: 418ms	remaining: 477ms
# 374:	learn: 0.0752342	total: 419ms	remaining: 475ms
# 375:	learn: 0.0751657	total: 420ms	remaining: 474ms
# 376:	learn: 0.0749880	total: 421ms	remaining: 473ms
# 377:	learn: 0.0748236	total: 422ms	remaining: 471ms
# 378:	learn: 0.0747568	total: 423ms	remaining: 470ms
# 379:	learn: 0.0747208	total: 424ms	remaining: 468ms
# 380:	learn: 0.0746558	total: 425ms	remaining: 467ms
# 381:	learn: 0.0746337	total: 426ms	remaining: 466ms
# 382:	learn: 0.0745314	total: 426ms	remaining: 464ms
# 383:	learn: 0.0743891	total: 427ms	remaining: 463ms
# 384:	learn: 0.0742865	total: 428ms	remaining: 462ms
# 385:	learn: 0.0742242	total: 429ms	remaining: 460ms
# 386:	learn: 0.0741626	total: 430ms	remaining: 459ms
# 387:	learn: 0.0739886	total: 431ms	remaining: 458ms
# 388:	learn: 0.0739390	total: 432ms	remaining: 456ms
# 389:	learn: 0.0738049	total: 433ms	remaining: 455ms
# 390:	learn: 0.0737052	total: 434ms	remaining: 454ms
# 391:	learn: 0.0735705	total: 435ms	remaining: 452ms
# 392:	learn: 0.0734999	total: 435ms	remaining: 451ms
# 393:	learn: 0.0734695	total: 437ms	remaining: 450ms
# 394:	learn: 0.0734326	total: 438ms	remaining: 449ms
# 395:	learn: 0.0732671	total: 439ms	remaining: 448ms
# 396:	learn: 0.0731696	total: 440ms	remaining: 446ms
# 397:	learn: 0.0730997	total: 441ms	remaining: 445ms
# 398:	learn: 0.0730031	total: 442ms	remaining: 444ms
# 399:	learn: 0.0728929	total: 442ms	remaining: 442ms
# 400:	learn: 0.0728172	total: 443ms	remaining: 441ms
# 401:	learn: 0.0726896	total: 444ms	remaining: 440ms
# 402:	learn: 0.0725775	total: 445ms	remaining: 439ms
# 403:	learn: 0.0724757	total: 446ms	remaining: 437ms
# 404:	learn: 0.0723819	total: 447ms	remaining: 436ms
# 405:	learn: 0.0723596	total: 448ms	remaining: 435ms
# 406:	learn: 0.0723271	total: 450ms	remaining: 434ms
# 407:	learn: 0.0722153	total: 451ms	remaining: 433ms
# 408:	learn: 0.0721788	total: 451ms	remaining: 432ms
# 409:	learn: 0.0720398	total: 452ms	remaining: 430ms
# 410:	learn: 0.0719356	total: 453ms	remaining: 429ms
# 411:	learn: 0.0717750	total: 454ms	remaining: 428ms
# 412:	learn: 0.0717190	total: 455ms	remaining: 427ms
# 413:	learn: 0.0716517	total: 456ms	remaining: 425ms
# 414:	learn: 0.0715937	total: 457ms	remaining: 424ms
# 415:	learn: 0.0714196	total: 458ms	remaining: 423ms
# 416:	learn: 0.0713123	total: 459ms	remaining: 422ms
# 417:	learn: 0.0712223	total: 461ms	remaining: 421ms
# 418:	learn: 0.0711963	total: 462ms	remaining: 420ms
# 419:	learn: 0.0711473	total: 463ms	remaining: 419ms
# 420:	learn: 0.0710476	total: 464ms	remaining: 418ms
# 421:	learn: 0.0709524	total: 465ms	remaining: 417ms
# 422:	learn: 0.0708882	total: 467ms	remaining: 416ms
# 423:	learn: 0.0707793	total: 468ms	remaining: 415ms
# 424:	learn: 0.0707330	total: 469ms	remaining: 414ms
# 425:	learn: 0.0706433	total: 470ms	remaining: 413ms
# 426:	learn: 0.0704998	total: 471ms	remaining: 411ms
# 427:	learn: 0.0704199	total: 472ms	remaining: 410ms
# 428:	learn: 0.0703041	total: 473ms	remaining: 409ms
# 429:	learn: 0.0702413	total: 474ms	remaining: 407ms
# 430:	learn: 0.0701554	total: 475ms	remaining: 406ms
# 431:	learn: 0.0700442	total: 475ms	remaining: 405ms
# 432:	learn: 0.0699587	total: 476ms	remaining: 404ms
# 433:	learn: 0.0698018	total: 477ms	remaining: 403ms
# 434:	learn: 0.0696949	total: 478ms	remaining: 401ms
# 435:	learn: 0.0696130	total: 479ms	remaining: 400ms
# 436:	learn: 0.0694816	total: 480ms	remaining: 399ms
# 437:	learn: 0.0694037	total: 481ms	remaining: 398ms
# 438:	learn: 0.0693213	total: 482ms	remaining: 396ms
# 439:	learn: 0.0691985	total: 483ms	remaining: 395ms
# 440:	learn: 0.0691278	total: 484ms	remaining: 394ms
# 441:	learn: 0.0691002	total: 485ms	remaining: 393ms
# 442:	learn: 0.0690820	total: 486ms	remaining: 392ms
# 443:	learn: 0.0689284	total: 487ms	remaining: 390ms
# 444:	learn: 0.0688516	total: 488ms	remaining: 389ms
# 445:	learn: 0.0688305	total: 489ms	remaining: 388ms
# 446:	learn: 0.0687445	total: 489ms	remaining: 386ms
# 447:	learn: 0.0686709	total: 490ms	remaining: 385ms
# 448:	learn: 0.0685680	total: 491ms	remaining: 384ms
# 449:	learn: 0.0685387	total: 492ms	remaining: 383ms
# 450:	learn: 0.0684838	total: 493ms	remaining: 382ms
# 451:	learn: 0.0683993	total: 494ms	remaining: 380ms
# 452:	learn: 0.0683903	total: 495ms	remaining: 379ms
# 453:	learn: 0.0682966	total: 496ms	remaining: 378ms
# 454:	learn: 0.0681899	total: 497ms	remaining: 377ms
# 455:	learn: 0.0681723	total: 498ms	remaining: 375ms
# 456:	learn: 0.0680903	total: 499ms	remaining: 374ms
# 457:	learn: 0.0680034	total: 500ms	remaining: 373ms
# 458:	learn: 0.0679544	total: 501ms	remaining: 372ms
# 459:	learn: 0.0678291	total: 501ms	remaining: 371ms
# 460:	learn: 0.0677682	total: 502ms	remaining: 369ms
# 461:	learn: 0.0676820	total: 503ms	remaining: 368ms
# 462:	learn: 0.0676060	total: 504ms	remaining: 367ms
# 463:	learn: 0.0675748	total: 505ms	remaining: 366ms
# 464:	learn: 0.0675200	total: 506ms	remaining: 365ms
# 465:	learn: 0.0673973	total: 507ms	remaining: 363ms
# 466:	learn: 0.0672991	total: 508ms	remaining: 362ms
# 467:	learn: 0.0671451	total: 509ms	remaining: 361ms
# 468:	learn: 0.0670725	total: 509ms	remaining: 359ms
# 469:	learn: 0.0669654	total: 510ms	remaining: 358ms
# 470:	learn: 0.0669286	total: 511ms	remaining: 357ms
# 471:	learn: 0.0668103	total: 512ms	remaining: 356ms
# 472:	learn: 0.0667509	total: 513ms	remaining: 355ms
# 473:	learn: 0.0666796	total: 514ms	remaining: 354ms
# 474:	learn: 0.0665559	total: 515ms	remaining: 352ms
# 475:	learn: 0.0664911	total: 516ms	remaining: 351ms
# 476:	learn: 0.0663996	total: 517ms	remaining: 350ms
# 477:	learn: 0.0662964	total: 518ms	remaining: 349ms
# 478:	learn: 0.0662384	total: 518ms	remaining: 347ms
# 479:	learn: 0.0662094	total: 520ms	remaining: 346ms
# 480:	learn: 0.0661204	total: 520ms	remaining: 345ms
# 481:	learn: 0.0660004	total: 521ms	remaining: 344ms
# 482:	learn: 0.0659157	total: 522ms	remaining: 343ms
# 483:	learn: 0.0657990	total: 523ms	remaining: 341ms
# 484:	learn: 0.0657107	total: 524ms	remaining: 340ms
# 485:	learn: 0.0656437	total: 525ms	remaining: 339ms
# 486:	learn: 0.0656242	total: 526ms	remaining: 338ms
# 487:	learn: 0.0655651	total: 527ms	remaining: 337ms
# 488:	learn: 0.0655485	total: 528ms	remaining: 335ms
# 489:	learn: 0.0654586	total: 529ms	remaining: 334ms
# 490:	learn: 0.0654442	total: 529ms	remaining: 333ms
# 491:	learn: 0.0653400	total: 530ms	remaining: 332ms
# 492:	learn: 0.0652825	total: 531ms	remaining: 331ms
# 493:	learn: 0.0652115	total: 532ms	remaining: 330ms
# 494:	learn: 0.0651333	total: 533ms	remaining: 329ms
# 495:	learn: 0.0650251	total: 534ms	remaining: 327ms
# 496:	learn: 0.0649561	total: 535ms	remaining: 326ms
# 497:	learn: 0.0648983	total: 536ms	remaining: 325ms
# 498:	learn: 0.0647790	total: 537ms	remaining: 324ms
# 499:	learn: 0.0647219	total: 538ms	remaining: 323ms
# 500:	learn: 0.0646617	total: 539ms	remaining: 321ms
# 501:	learn: 0.0646096	total: 540ms	remaining: 320ms
# 502:	learn: 0.0644844	total: 540ms	remaining: 319ms
# 503:	learn: 0.0644084	total: 541ms	remaining: 318ms
# 504:	learn: 0.0643751	total: 542ms	remaining: 317ms
# 505:	learn: 0.0643143	total: 543ms	remaining: 316ms
# 506:	learn: 0.0642451	total: 544ms	remaining: 314ms
# 507:	learn: 0.0641937	total: 545ms	remaining: 313ms
# 508:	learn: 0.0641053	total: 546ms	remaining: 312ms
# 509:	learn: 0.0640486	total: 547ms	remaining: 311ms
# 510:	learn: 0.0639936	total: 548ms	remaining: 310ms
# 511:	learn: 0.0639383	total: 549ms	remaining: 309ms
# 512:	learn: 0.0638522	total: 550ms	remaining: 308ms
# 513:	learn: 0.0638407	total: 551ms	remaining: 306ms
# 514:	learn: 0.0637250	total: 552ms	remaining: 305ms
# 515:	learn: 0.0636299	total: 553ms	remaining: 304ms
# 516:	learn: 0.0636094	total: 554ms	remaining: 303ms
# 517:	learn: 0.0635286	total: 555ms	remaining: 302ms
# 518:	learn: 0.0634081	total: 556ms	remaining: 301ms
# 519:	learn: 0.0633022	total: 557ms	remaining: 300ms
# 520:	learn: 0.0632470	total: 558ms	remaining: 299ms
# 521:	learn: 0.0631692	total: 559ms	remaining: 298ms
# 522:	learn: 0.0630954	total: 560ms	remaining: 297ms
# 523:	learn: 0.0630536	total: 561ms	remaining: 295ms
# 524:	learn: 0.0629816	total: 562ms	remaining: 294ms
# 525:	learn: 0.0629072	total: 563ms	remaining: 293ms
# 526:	learn: 0.0628320	total: 564ms	remaining: 292ms
# 527:	learn: 0.0626708	total: 565ms	remaining: 291ms
# 528:	learn: 0.0625985	total: 566ms	remaining: 290ms
# 529:	learn: 0.0625674	total: 567ms	remaining: 289ms
# 530:	learn: 0.0625421	total: 568ms	remaining: 288ms
# 531:	learn: 0.0624465	total: 569ms	remaining: 287ms
# 532:	learn: 0.0623738	total: 570ms	remaining: 285ms
# 533:	learn: 0.0623230	total: 571ms	remaining: 284ms
# 534:	learn: 0.0622252	total: 572ms	remaining: 283ms
# 535:	learn: 0.0621165	total: 573ms	remaining: 282ms
# 536:	learn: 0.0620137	total: 574ms	remaining: 281ms
# 537:	learn: 0.0619703	total: 575ms	remaining: 280ms
# 538:	learn: 0.0619264	total: 575ms	remaining: 279ms
# 539:	learn: 0.0618747	total: 576ms	remaining: 278ms
# 540:	learn: 0.0618257	total: 577ms	remaining: 276ms
# 541:	learn: 0.0617542	total: 578ms	remaining: 275ms
# 542:	learn: 0.0617355	total: 579ms	remaining: 274ms
# 543:	learn: 0.0616651	total: 580ms	remaining: 273ms
# 544:	learn: 0.0616503	total: 581ms	remaining: 272ms
# 545:	learn: 0.0615999	total: 582ms	remaining: 271ms
# 546:	learn: 0.0614768	total: 583ms	remaining: 269ms
# 547:	learn: 0.0614109	total: 584ms	remaining: 268ms
# 548:	learn: 0.0613343	total: 585ms	remaining: 267ms
# 549:	learn: 0.0612608	total: 585ms	remaining: 266ms
# 550:	learn: 0.0611686	total: 586ms	remaining: 265ms
# 551:	learn: 0.0610805	total: 587ms	remaining: 264ms
# 552:	learn: 0.0609999	total: 588ms	remaining: 263ms
# 553:	learn: 0.0609801	total: 589ms	remaining: 262ms
# 554:	learn: 0.0609669	total: 590ms	remaining: 260ms
# 555:	learn: 0.0609482	total: 591ms	remaining: 259ms
# 556:	learn: 0.0609305	total: 592ms	remaining: 258ms
# 557:	learn: 0.0608056	total: 593ms	remaining: 257ms
# 558:	learn: 0.0607258	total: 594ms	remaining: 256ms
# 559:	learn: 0.0607053	total: 595ms	remaining: 255ms
# 560:	learn: 0.0606792	total: 595ms	remaining: 254ms
# 561:	learn: 0.0606045	total: 596ms	remaining: 253ms
# 562:	learn: 0.0605346	total: 597ms	remaining: 251ms
# 563:	learn: 0.0604829	total: 598ms	remaining: 250ms
# 564:	learn: 0.0604011	total: 599ms	remaining: 249ms
# 565:	learn: 0.0603162	total: 600ms	remaining: 248ms
# 566:	learn: 0.0601996	total: 601ms	remaining: 247ms
# 567:	learn: 0.0601499	total: 602ms	remaining: 246ms
# 568:	learn: 0.0601373	total: 604ms	remaining: 245ms
# 569:	learn: 0.0600952	total: 605ms	remaining: 244ms
# 570:	learn: 0.0600673	total: 606ms	remaining: 243ms
# 571:	learn: 0.0600576	total: 607ms	remaining: 242ms
# 572:	learn: 0.0599871	total: 608ms	remaining: 241ms
# 573:	learn: 0.0599662	total: 609ms	remaining: 240ms
# 574:	learn: 0.0599351	total: 610ms	remaining: 239ms
# 575:	learn: 0.0598222	total: 611ms	remaining: 238ms
# 576:	learn: 0.0597455	total: 612ms	remaining: 237ms
# 577:	learn: 0.0596978	total: 613ms	remaining: 235ms
# 578:	learn: 0.0595928	total: 614ms	remaining: 235ms
# 579:	learn: 0.0595435	total: 615ms	remaining: 233ms
# 580:	learn: 0.0594907	total: 616ms	remaining: 232ms
# 581:	learn: 0.0594480	total: 617ms	remaining: 231ms
# 582:	learn: 0.0593625	total: 618ms	remaining: 230ms
# 583:	learn: 0.0593155	total: 619ms	remaining: 229ms
# 584:	learn: 0.0592399	total: 620ms	remaining: 228ms
# 585:	learn: 0.0591765	total: 621ms	remaining: 227ms
# 586:	learn: 0.0590883	total: 622ms	remaining: 226ms
# 587:	learn: 0.0590193	total: 623ms	remaining: 225ms
# 588:	learn: 0.0589706	total: 624ms	remaining: 223ms
# 589:	learn: 0.0589074	total: 625ms	remaining: 222ms
# 590:	learn: 0.0588992	total: 626ms	remaining: 221ms
# 591:	learn: 0.0588049	total: 626ms	remaining: 220ms
# 592:	learn: 0.0587052	total: 628ms	remaining: 219ms
# 593:	learn: 0.0586598	total: 628ms	remaining: 218ms
# 594:	learn: 0.0585790	total: 629ms	remaining: 217ms
# 595:	learn: 0.0584699	total: 631ms	remaining: 216ms
# 596:	learn: 0.0584031	total: 632ms	remaining: 215ms
# 597:	learn: 0.0583373	total: 633ms	remaining: 214ms
# 598:	learn: 0.0582603	total: 633ms	remaining: 213ms
# 599:	learn: 0.0582369	total: 635ms	remaining: 212ms
# 600:	learn: 0.0581389	total: 635ms	remaining: 210ms
# 601:	learn: 0.0581331	total: 636ms	remaining: 209ms
# 602:	learn: 0.0580463	total: 637ms	remaining: 208ms
# 603:	learn: 0.0579920	total: 638ms	remaining: 207ms
# 604:	learn: 0.0579416	total: 640ms	remaining: 206ms
# 605:	learn: 0.0578946	total: 641ms	remaining: 205ms
# 606:	learn: 0.0577872	total: 642ms	remaining: 204ms
# 607:	learn: 0.0577318	total: 643ms	remaining: 203ms
# 608:	learn: 0.0576748	total: 644ms	remaining: 202ms
# 609:	learn: 0.0576371	total: 645ms	remaining: 201ms
# 610:	learn: 0.0575778	total: 646ms	remaining: 200ms
# 611:	learn: 0.0575623	total: 648ms	remaining: 199ms
# 612:	learn: 0.0575152	total: 649ms	remaining: 198ms
# 613:	learn: 0.0574788	total: 650ms	remaining: 197ms
# 614:	learn: 0.0574035	total: 650ms	remaining: 196ms
# 615:	learn: 0.0573345	total: 651ms	remaining: 195ms
# 616:	learn: 0.0572657	total: 652ms	remaining: 193ms
# 617:	learn: 0.0571470	total: 653ms	remaining: 192ms
# 618:	learn: 0.0570480	total: 654ms	remaining: 191ms
# 619:	learn: 0.0570156	total: 655ms	remaining: 190ms
# 620:	learn: 0.0569298	total: 656ms	remaining: 189ms
# 621:	learn: 0.0568533	total: 658ms	remaining: 188ms
# 622:	learn: 0.0567500	total: 659ms	remaining: 187ms
# 623:	learn: 0.0567172	total: 660ms	remaining: 186ms
# 624:	learn: 0.0566215	total: 661ms	remaining: 185ms
# 625:	learn: 0.0565678	total: 662ms	remaining: 184ms
# 626:	learn: 0.0564491	total: 663ms	remaining: 183ms
# 627:	learn: 0.0563577	total: 664ms	remaining: 182ms
# 628:	learn: 0.0563204	total: 665ms	remaining: 181ms
# 629:	learn: 0.0562391	total: 666ms	remaining: 180ms
# 630:	learn: 0.0561578	total: 666ms	remaining: 178ms
# 631:	learn: 0.0560698	total: 668ms	remaining: 177ms
# 632:	learn: 0.0559854	total: 668ms	remaining: 176ms
# 633:	learn: 0.0559750	total: 669ms	remaining: 175ms
# 634:	learn: 0.0559081	total: 670ms	remaining: 174ms
# 635:	learn: 0.0558783	total: 671ms	remaining: 173ms
# 636:	learn: 0.0558692	total: 672ms	remaining: 172ms
# 637:	learn: 0.0558499	total: 673ms	remaining: 171ms
# 638:	learn: 0.0558051	total: 674ms	remaining: 170ms
# 639:	learn: 0.0557455	total: 675ms	remaining: 169ms
# 640:	learn: 0.0556549	total: 676ms	remaining: 168ms
# 641:	learn: 0.0555961	total: 677ms	remaining: 167ms
# 642:	learn: 0.0555678	total: 678ms	remaining: 166ms
# 643:	learn: 0.0555269	total: 679ms	remaining: 164ms
# 644:	learn: 0.0554840	total: 680ms	remaining: 163ms
# 645:	learn: 0.0553975	total: 681ms	remaining: 162ms
# 646:	learn: 0.0553744	total: 682ms	remaining: 161ms
# 647:	learn: 0.0553553	total: 682ms	remaining: 160ms
# 648:	learn: 0.0552507	total: 683ms	remaining: 159ms
# 649:	learn: 0.0552245	total: 685ms	remaining: 158ms
# 650:	learn: 0.0551584	total: 686ms	remaining: 157ms
# 651:	learn: 0.0551462	total: 687ms	remaining: 156ms
# 652:	learn: 0.0550988	total: 687ms	remaining: 155ms
# 653:	learn: 0.0550873	total: 688ms	remaining: 154ms
# 654:	learn: 0.0550377	total: 689ms	remaining: 153ms
# 655:	learn: 0.0550316	total: 691ms	remaining: 152ms
# 656:	learn: 0.0549744	total: 692ms	remaining: 151ms
# 657:	learn: 0.0548987	total: 693ms	remaining: 149ms
# 658:	learn: 0.0548327	total: 693ms	remaining: 148ms
# 659:	learn: 0.0548074	total: 695ms	remaining: 147ms
# 660:	learn: 0.0547511	total: 696ms	remaining: 146ms
# 661:	learn: 0.0546554	total: 696ms	remaining: 145ms
# 662:	learn: 0.0546036	total: 697ms	remaining: 144ms
# 663:	learn: 0.0545410	total: 698ms	remaining: 143ms
# 664:	learn: 0.0544412	total: 700ms	remaining: 142ms
# 665:	learn: 0.0543844	total: 701ms	remaining: 141ms
# 666:	learn: 0.0543166	total: 702ms	remaining: 140ms
# 667:	learn: 0.0542962	total: 703ms	remaining: 139ms
# 668:	learn: 0.0542558	total: 703ms	remaining: 138ms
# 669:	learn: 0.0541983	total: 704ms	remaining: 137ms
# 670:	learn: 0.0541842	total: 705ms	remaining: 136ms
# 671:	learn: 0.0541268	total: 706ms	remaining: 135ms
# 672:	learn: 0.0540858	total: 707ms	remaining: 133ms
# 673:	learn: 0.0540098	total: 708ms	remaining: 132ms
# 674:	learn: 0.0539298	total: 709ms	remaining: 131ms
# 675:	learn: 0.0538793	total: 710ms	remaining: 130ms
# 676:	learn: 0.0538093	total: 711ms	remaining: 129ms
# 677:	learn: 0.0537628	total: 712ms	remaining: 128ms
# 678:	learn: 0.0537521	total: 713ms	remaining: 127ms
# 679:	learn: 0.0536995	total: 713ms	remaining: 126ms
# 680:	learn: 0.0536293	total: 714ms	remaining: 125ms
# 681:	learn: 0.0535420	total: 715ms	remaining: 124ms
# 682:	learn: 0.0535288	total: 716ms	remaining: 123ms
# 683:	learn: 0.0534587	total: 717ms	remaining: 122ms
# 684:	learn: 0.0534071	total: 718ms	remaining: 121ms
# 685:	learn: 0.0533655	total: 719ms	remaining: 119ms
# 686:	learn: 0.0532914	total: 720ms	remaining: 118ms
# 687:	learn: 0.0531984	total: 721ms	remaining: 117ms
# 688:	learn: 0.0531434	total: 722ms	remaining: 116ms
# 689:	learn: 0.0531050	total: 723ms	remaining: 115ms
# 690:	learn: 0.0530351	total: 724ms	remaining: 114ms
# 691:	learn: 0.0529583	total: 725ms	remaining: 113ms
# 692:	learn: 0.0529409	total: 726ms	remaining: 112ms
# 693:	learn: 0.0528712	total: 726ms	remaining: 111ms
# 694:	learn: 0.0528003	total: 727ms	remaining: 110ms
# 695:	learn: 0.0527354	total: 728ms	remaining: 109ms
# 696:	learn: 0.0526598	total: 729ms	remaining: 108ms
# 697:	learn: 0.0526473	total: 730ms	remaining: 107ms
# 698:	learn: 0.0525771	total: 731ms	remaining: 106ms
# 699:	learn: 0.0524950	total: 732ms	remaining: 105ms
# 700:	learn: 0.0524732	total: 733ms	remaining: 103ms
# 701:	learn: 0.0524401	total: 734ms	remaining: 102ms
# 702:	learn: 0.0524272	total: 734ms	remaining: 101ms
# 703:	learn: 0.0523649	total: 736ms	remaining: 100ms
# 704:	learn: 0.0523233	total: 737ms	remaining: 99.3ms
# 705:	learn: 0.0522605	total: 738ms	remaining: 98.2ms
# 706:	learn: 0.0521686	total: 738ms	remaining: 97.1ms
# 707:	learn: 0.0521076	total: 739ms	remaining: 96.1ms
# 708:	learn: 0.0520521	total: 740ms	remaining: 95ms
# 709:	learn: 0.0520159	total: 742ms	remaining: 94.1ms
# 710:	learn: 0.0519864	total: 743ms	remaining: 93ms
# 711:	learn: 0.0519744	total: 744ms	remaining: 91.9ms
# 712:	learn: 0.0519201	total: 745ms	remaining: 90.9ms
# 713:	learn: 0.0518344	total: 746ms	remaining: 89.8ms
# 714:	learn: 0.0517622	total: 747ms	remaining: 88.8ms
# 715:	learn: 0.0516845	total: 748ms	remaining: 87.7ms
# 716:	learn: 0.0516226	total: 749ms	remaining: 86.7ms
# 717:	learn: 0.0516070	total: 750ms	remaining: 85.7ms
# 718:	learn: 0.0515167	total: 751ms	remaining: 84.6ms
# 719:	learn: 0.0514738	total: 752ms	remaining: 83.6ms
# 720:	learn: 0.0514001	total: 753ms	remaining: 82.5ms
# 721:	learn: 0.0513728	total: 754ms	remaining: 81.5ms
# 722:	learn: 0.0512836	total: 755ms	remaining: 80.4ms
# 723:	learn: 0.0512408	total: 756ms	remaining: 79.4ms
# 724:	learn: 0.0511790	total: 757ms	remaining: 78.3ms
# 725:	learn: 0.0511368	total: 758ms	remaining: 77.3ms
# 726:	learn: 0.0510760	total: 759ms	remaining: 76.2ms
# 727:	learn: 0.0510152	total: 760ms	remaining: 75.2ms
# 728:	learn: 0.0509568	total: 761ms	remaining: 74.1ms
# 729:	learn: 0.0509151	total: 762ms	remaining: 73.1ms
# 730:	learn: 0.0508394	total: 763ms	remaining: 72ms
# 731:	learn: 0.0507798	total: 764ms	remaining: 71ms
# 732:	learn: 0.0507431	total: 765ms	remaining: 69.9ms
# 733:	learn: 0.0507335	total: 766ms	remaining: 68.9ms
# 734:	learn: 0.0506923	total: 767ms	remaining: 67.8ms
# 735:	learn: 0.0506021	total: 768ms	remaining: 66.8ms
# 736:	learn: 0.0505588	total: 769ms	remaining: 65.7ms
# 737:	learn: 0.0505123	total: 770ms	remaining: 64.7ms
# 738:	learn: 0.0504483	total: 770ms	remaining: 63.6ms
# 739:	learn: 0.0504052	total: 771ms	remaining: 62.5ms
# 740:	learn: 0.0503711	total: 772ms	remaining: 61.5ms
# 741:	learn: 0.0502985	total: 773ms	remaining: 60.4ms
# 742:	learn: 0.0502207	total: 774ms	remaining: 59.4ms
# 743:	learn: 0.0501942	total: 775ms	remaining: 58.3ms
# 744:	learn: 0.0501222	total: 776ms	remaining: 57.3ms
# 745:	learn: 0.0500677	total: 777ms	remaining: 56.3ms
# 746:	learn: 0.0500197	total: 778ms	remaining: 55.2ms
# 747:	learn: 0.0499516	total: 779ms	remaining: 54.2ms
# 748:	learn: 0.0499101	total: 780ms	remaining: 53.1ms
# 749:	learn: 0.0498906	total: 781ms	remaining: 52.1ms
# 750:	learn: 0.0498033	total: 782ms	remaining: 51ms
# 751:	learn: 0.0497306	total: 783ms	remaining: 50ms
# 752:	learn: 0.0496585	total: 784ms	remaining: 48.9ms
# 753:	learn: 0.0496004	total: 785ms	remaining: 47.9ms
# 754:	learn: 0.0495435	total: 785ms	remaining: 46.8ms
# 755:	learn: 0.0495170	total: 786ms	remaining: 45.8ms
# 756:	learn: 0.0494886	total: 787ms	remaining: 44.7ms
# 757:	learn: 0.0494555	total: 788ms	remaining: 43.7ms
# 758:	learn: 0.0493997	total: 789ms	remaining: 42.6ms
# 759:	learn: 0.0493584	total: 790ms	remaining: 41.6ms
# 760:	learn: 0.0493070	total: 791ms	remaining: 40.5ms
# 761:	learn: 0.0492951	total: 792ms	remaining: 39.5ms
# 762:	learn: 0.0492375	total: 793ms	remaining: 38.4ms
# 763:	learn: 0.0491955	total: 794ms	remaining: 37.4ms
# 764:	learn: 0.0491837	total: 794ms	remaining: 36.3ms
# 765:	learn: 0.0491234	total: 796ms	remaining: 35.3ms
# 766:	learn: 0.0490633	total: 797ms	remaining: 34.3ms
# 767:	learn: 0.0489981	total: 798ms	remaining: 33.2ms
# 768:	learn: 0.0489427	total: 798ms	remaining: 32.2ms
# 769:	learn: 0.0488851	total: 799ms	remaining: 31.1ms
# 770:	learn: 0.0488804	total: 800ms	remaining: 30.1ms
# 771:	learn: 0.0488233	total: 801ms	remaining: 29.1ms
# 772:	learn: 0.0487651	total: 802ms	remaining: 28ms
# 773:	learn: 0.0487079	total: 803ms	remaining: 27ms
# 774:	learn: 0.0486334	total: 804ms	remaining: 25.9ms
# 775:	learn: 0.0485769	total: 805ms	remaining: 24.9ms
# 776:	learn: 0.0484869	total: 806ms	remaining: 23.9ms
# 777:	learn: 0.0484632	total: 807ms	remaining: 22.8ms
# 778:	learn: 0.0484379	total: 808ms	remaining: 21.8ms
# 779:	learn: 0.0484345	total: 809ms	remaining: 20.7ms
# 780:	learn: 0.0483737	total: 810ms	remaining: 19.7ms
# 781:	learn: 0.0483222	total: 812ms	remaining: 18.7ms
# 782:	learn: 0.0482673	total: 813ms	remaining: 17.6ms
# 783:	learn: 0.0482146	total: 814ms	remaining: 16.6ms
# 784:	learn: 0.0481466	total: 815ms	remaining: 15.6ms
# 785:	learn: 0.0481070	total: 816ms	remaining: 14.5ms
# 786:	learn: 0.0481002	total: 817ms	remaining: 13.5ms
# 787:	learn: 0.0480862	total: 818ms	remaining: 12.5ms
# 788:	learn: 0.0480382	total: 819ms	remaining: 11.4ms
# 789:	learn: 0.0480280	total: 820ms	remaining: 10.4ms
# 790:	learn: 0.0479947	total: 821ms	remaining: 9.34ms
# 791:	learn: 0.0479315	total: 822ms	remaining: 8.3ms
# 792:	learn: 0.0478941	total: 823ms	remaining: 7.27ms
# 793:	learn: 0.0478434	total: 825ms	remaining: 6.23ms
# 794:	learn: 0.0477814	total: 826ms	remaining: 5.19ms
# 795:	learn: 0.0477582	total: 827ms	remaining: 4.16ms
# 796:	learn: 0.0476744	total: 828ms	remaining: 3.12ms
# 797:	learn: 0.0476067	total: 829ms	remaining: 2.08ms
# 798:	learn: 0.0475686	total: 830ms	remaining: 1.04ms
# 799:	learn: 0.0475081	total: 831ms	remaining: 0us
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputer',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('replace',
#                                                                    SimpleImputer(fill_value='Unknown',
#                                                                                  strategy='constant'),
#                                                                    ['MasVnrType',
#                                                                     'BsmtQual',
#                                                                     'BsmtCond',
#                                                                     'BsmtExposure',
#                                                                     'BsmtFinType1',
#                                                                     'BsmtFinType2',
#                                                                     'FireplaceQu',
#                                                                     'GarageType',
#                                                                     'GarageFinish',
#                                                                     'GarageQual',
#                                                                     'GarageCond',
#                                                                     'PoolQC',
#                                                                     'Fence',
#                                                                     'M...
#                                                                     'BedroomAbvGr',
#                                                                     'KitchenAbvGr',
#                                                                     'TotRmsAbvGrd',
#                                                                     'Fireplaces',
#                                                                     'GarageYrBlt',
#                                                                     'GarageCars',
#                                                                     'GarageArea',
#                                                                     'WoodDeckSF',
#                                                                     'OpenPorchSF',
#                                                                     'EnclosedPorch',
#                                                                     '3SsnPorch',
#                                                                     'ScreenPorch',
#                                                                     'PoolArea',
#                                                                     'MiscVal',
#                                                                     'MoSold',
#                                                                     'TotalSF',
#                                                                     'OverallGrade',
#                                                                     'AgeAtSale',
#                                                                     'TotalBathrooms'])],
#                                                     verbose_feature_names_out=False))])),
#                 ('model',
#                  <catboost.core.CatBoostRegressor object at 0x15a631520>)])

# %% [markdown]
# ### Строим предсказание на тестовой части выборки и записываем в файл Submission.csv

# %%
# y_pred = ml_pipeline_CB.predict(X_valid)
# rmlse = root_mean_squared_log_error(Y_valid, y_pred)
# y_pred = np.expm1(y_pred)
# rmlse
# print(f"RMSLE для CatBoost: {rmlse}")

# %%
y_pred = ml_pipeline_CB.predict(test)
y_pred = np.expm1(y_pred)
submission_cb = pd.DataFrame({'Id': test.index, 'SalePrice': y_pred})

# %%
submission_cb.to_csv('submission.csv', index=False)

# %%
joblib.dump(ml_pipeline_CB, 'model_pipeline.pkl')
# Out:
# ['model_pipeline.pkl']
